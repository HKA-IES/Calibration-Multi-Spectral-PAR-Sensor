# %%
import Calibration as cal

# %%
path = r"../data"
sensor_type = "Calibration"

# %%
for sensor_nr in range(1, 5):
    sensor_instance = cal.Calibration(path, sensor_nr, sensor_type)
    if sensor_instance.preprocessing(save_data=False):
        sensor_instance.pls(save_coef=False, PAR=False)
        #sensor_instance.plot_gaussian()
        #sensor_instance.plot_quantum_response()
        sensor_instance.plot_energy_response()
# Out:
# Found matching files:
# Calibration.2025.sensor1.csv
# Beamsplitter data loaded
# Max R2 is reached with 8 PLS components
# R2: 0.8527, RMSE: 0.19109149
# f1:	8.166965234342522
# f2:	4.511993292458017
# f3:	3.0205491819609454
# f4:	2.314961693324389
# f5:	1.9885528552855285
# f6:	1.5199232131028755
# f7:	1.3249591904257805
# f8:	0.9821819710872466
# clear:	-1.2272751151650514
# nir:	0.05726402866556833
# Found matching files:
# Calibration.2025.sensor2.csv
# Beamsplitter data loaded
# Max R2 is reached with 6 PLS components
# R2: 0.8139, RMSE: 0.21477707
# f1:	10.486297752069278
# f2:	5.622367286749721
# f3:	4.188057194275077
# f4:	3.524771648971461
# f5:	2.8653300062304043
# f6:	2.201200265972613
# f7:	2.409960778713206
# f8:	1.5376897323511363
# clear:	-1.2673103194941797
# nir:	0.07090202271230031
# Found matching files:
# Calibration.2025.sensor3.csv
# Beamsplitter data loaded
# Max R2 is reached with 6 PLS components
# R2: 0.9236, RMSE: 0.13758979
# f1:	10.715572933246204
# f2:	5.651043526690871
# f3:	4.249558142321445
# f4:	3.4518386798873024
# f5:	2.8649751063952364
# f6:	2.4021706808287333
# f7:	2.4036030343354855
# f8:	1.7423707481452264
# clear:	-1.431636521077542
# nir:	0.08600894090332487
# Found matching files:
# Calibration.2025.sensor4.csv
# Beamsplitter data loaded
# Max R2 is reached with 10 PLS components
# R2: 0.8856, RMSE: 0.16839123
# f1:	11.95909647554558
# f2:	6.944077211059175
# f3:	5.352818676595752
# f4:	4.347657267784667
# f5:	3.4758085171015627
# f6:	2.6928538000576165
# f7:	3.152957520619861
# f8:	2.3192126975722616
# clear:	-1.7813993484354582
# nir:	0.10365994804913733
