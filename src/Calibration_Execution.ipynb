# %%
import Calibration as cal

# %%
path = r"../data"
sensor_type = "Calibration"

# %%
for sensor_nr in range(1, 5):
    sensor_instance = cal.Calibration(path, sensor_nr, sensor_type)
    if sensor_instance.preprocessing(save_data=False, spectrum="PAR"):
        sensor_instance.regression(reg = "pls",save_coef=False)
        #sensor_instance.plot_gaussian(save=False)
        sensor_instance.plot_quantum_response()
# Out:
# Found matching files:
# Calibration.2025.sensor1.csv
# Max R2 is reached with 9 PLS components
# max R2: 0.9572, min RMSE: 0.48770102
# Coefficients (comma-separated): 29.108946610146152, 16.993525664699863, 12.127935858687207, 9.90066117854177, 9.043197945497047, 7.284017350592741, 6.791615902704746, 5.465064145146927, -5.04623909125897, 0.2518220234962543
# Quantum Response R2: 0.9359, RMSE: 0.59726394
# Found matching files:
# Calibration.2025.sensor2.csv
# Max R2 is reached with 10 PLS components
# max R2: 0.9447, min RMSE: 0.55483057
# Coefficients (comma-separated): 37.29822553149396, 21.291222229315995, 16.977602475753958, 15.278669492998084, 13.322751257321832, 10.692847587674859, 12.61889924682116, 8.68316158504487, -5.38075056378027, 0.331037855568525
# Quantum Response R2: 0.9440, RMSE: 0.55833044
# Found matching files:
# Calibration.2025.sensor3.csv
# Max R2 is reached with 10 PLS components
# max R2: 0.9562, min RMSE: 0.49369883
# Coefficients (comma-separated): 38.05760244729023, 21.30396580269743, 17.15689136452774, 14.905911881008123, 13.225272506405137, 11.654633255244267, 12.54029222913494, 9.844608499158001, -6.057417395606241, 0.39188681744877535
# Quantum Response R2: 0.9536, RMSE: 0.50812723
# Found matching files:
# Calibration.2025.sensor4.csv
# Max R2 is reached with 10 PLS components
# max R2: 0.9594, min RMSE: 0.47494050
# Coefficients (comma-separated): 42.49456025023034, 26.14436947559341, 21.52161135414673, 18.65942096946249, 15.972199495931978, 12.937280747443392, 16.17174913003476, 12.96102214528994, -7.470081382752716, 0.4418731968022496
# Quantum Response R2: 0.9580, RMSE: 0.48346609
