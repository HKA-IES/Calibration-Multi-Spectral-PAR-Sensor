# %%
import Calibration as cal

# %%
path = r"../data"
sensor_type = "Calibration"

# %%
for sensor_nr in range(1, 5):
    sensor_instance = cal.Calibration(path, sensor_nr, sensor_type)
    if sensor_instance.preprocessing(save_data=False):
        sensor_instance.pls(save_coef=False)
        sensor_instance.plot_gaussian(save=False)
        sensor_instance.plot_quantum_response()
# Out:
# Found matching files:
# Calibration.2025.sensor1.csv
# Coefficients: 29.11024906826017, 16.9939655307408, 12.12624803747697, 9.901982375441948, 9.042761980427278, 7.284044445211508, 6.791485333465561, 5.4651270923709445, -5.046215405876729, 0.2517810735710138
# Found matching files:
# Calibration.2025.sensor2.csv
# Coefficients: 37.29792177789769, 21.262297900993367, 16.97708091868878, 15.273172741787826, 13.322099267749344, 10.722226448569403, 12.603456126506261, 8.685011472704995, -5.392285634902561, 0.3293555215696629
# Found matching files:
# Calibration.2025.sensor3.csv
# Coefficients: 38.05196424495017, 21.2806692397086, 17.154453715770284, 14.894713879313365, 13.227683720750495, 11.686852936708064, 12.516697064035778, 9.850906196547745, -6.069419866752719, 0.3890088719154622
# Found matching files:
# Calibration.2025.sensor4.csv
# Coefficients: 42.49675613158447, 26.139274556590813, 21.524250184394386, 18.66096017047156, 15.967648379605182, 12.940516821213984, 16.170514930093518, 12.961724536616916, -7.470744826175291, 0.44167143908077555
